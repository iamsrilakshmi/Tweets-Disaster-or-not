# %%
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('/content/drive/My Drive/Tweets/3. Feature Engineering/tweets_train_features.csv')
train[:2]
# Out:
#    keyword  ...                             no_pronoun
# 0  missing  ...  deeds reason earthquake allah forgive
# 1  missing  ...  forest fire near la ronge sask canada
#
# [2 rows x 25 columns]

# %%
train.shape
# Out:
# (7613, 25)

# %%
x = train.copy()

# %% [markdown]
# # SPLIT THE DATA INTO 3 SETS :
#
# # SET-1 : 50 %
#
# # SET-2 : 25 %
#
# # SET-3 : 25 %

# %%
x1, xx = train_test_split(x, test_size = 0.5)
x2, x3 = train_test_split(xx, test_size = 0.5)

# %%
print(x1.shape)
print(x2.shape)
print(x3.shape)
# Out:
# (3806, 25)
# (1903, 25)
# (1904, 25)

# %% [markdown]
# # Save the split data sets in Drive for future use

# %%
x1.to_csv('set1.csv', index=False)
# !cp set1.csv "drive/My Drive/Tweets/3. Feature Engineering/"

x2.to_csv('set2.csv', index=False)
# !cp set2.csv "drive/My Drive/Tweets/3. Feature Engineering/"

x3.to_csv('set3.csv', index=False)
# !cp set3.csv "drive/My Drive/Tweets/3. Feature Engineering/"
